# %%
pip install -e llec_building_gym
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///hkfs/home/haicore/iai/gc3089/Gokhan/llec_building_gym
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: llec-building-gym
#     Found existing installation: llec-building-gym 0.1.0
#     Not uninstalling llec-building-gym at /hkfs/home/haicore/iai/gc3089/Gokhan/llec_building_gym, outside environment /software/all/jupyter/ai/2025-05-23
#     Can't uninstall 'llec-building-gym'. No files were found to uninstall.
# ...

# %%
# !python run_train_rl.py --algorithm ddpg --reward_mode temperature --obs_variant T01 --training --seed 18 --timesteps 1e5
# Out:
# 2026-02-23 11:49:59.824711: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-23 11:49:59.838490: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771843799.851524  568995 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771843799.855440  568995 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python run_evaluation.py --algorithms ddpg  --reward_mode temperature --obs_variant T01 --prefer_best --outdoor_temperature_path "data/LLEC_outdoor_temperature_1min_data.csv"
# Out:
# 2026-02-23 11:58:38.294936: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-23 11:58:38.309118: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771844318.324280  571700 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771844318.328417  571700 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
